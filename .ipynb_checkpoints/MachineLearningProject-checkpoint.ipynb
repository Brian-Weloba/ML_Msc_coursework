# %% [markdown]
# # Machine Learning Project
# **Author:** Brian Weloba - 14574430
#
# **Dataset:** AIDS Virus Infection Prediction

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# Import required packages:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.svm import SVC

# %% [markdown]
# Import the dataset:

# %%
df_aids = pd.read_csv('AIDS_Classification.csv')

# %% [markdown]
# Inspect the dataframe object:

# %%
df_aids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2139 entries, 0 to 2138
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   time      2139 non-null   int64
#  1   trt       2139 non-null   int64
#  2   age       2139 non-null   int64
#  3   wtkg      2139 non-null   float64
#  4   hemo      2139 non-null   int64
#  5   homo      2139 non-null   int64
#  6   drugs     2139 non-null   int64
#  7   karnof    2139 non-null   int64
#  8   oprior    2139 non-null   int64
#  9   z30       2139 non-null   int64
#  10  preanti   2139 non-null   int64
#  11  race      2139 non-null   int64
#  12  gender    2139 non-null   int64
#  13  str2      2139 non-null   int64
#  14  strat     2139 non-null   int64
#  15  symptom   2139 non-null   int64
#  16  treat     2139 non-null   int64
#  17  offtrt    2139 non-null   int64
#  18  cd40      2139 non-null   int64
#  19  cd420     2139 non-null   int64
#  20  cd80      2139 non-null   int64
#  21  cd820     2139 non-null   int64
#  22  infected  2139 non-null   int64
# dtypes: float64(1), int64(22)
# memory usage: 384.5 KB

# %% [markdown]
# Check for null values:

# %%
pd.DataFrame(df_aids.isna().sum()).T.style.background_gradient(cmap=default_color_palette)
# Out:
# <style type="text/css">
# #T_a933d_row0_col0, #T_a933d_row0_col1, #T_a933d_row0_col2, #T_a933d_row0_col3, #T_a933d_row0_col4, #T_a933d_row0_col5, #T_a933d_row0_col6, #T_a933d_row0_col7, #T_a933d_row0_col8, #T_a933d_row0_col9, #T_a933d_row0_col10, #T_a933d_row0_col11, #T_a933d_row0_col12, #T_a933d_row0_col13, #T_a933d_row0_col14, #T_a933d_row0_col15, #T_a933d_row0_col16, #T_a933d_row0_col17, #T_a933d_row0_col18, #T_a933d_row0_col19, #T_a933d_row0_col20, #T_a933d_row0_col21, #T_a933d_row0_col22 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a933d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a933d_level0_col0" class="col_heading level0 col0" >time</th>
#       <th id="T_a933d_level0_col1" class="col_heading level0 col1" >trt</th>
#       <th id="T_a933d_level0_col2" class="col_heading level0 col2" >age</th>
#       <th id="T_a933d_level0_col3" class="col_heading level0 col3" >wtkg</th>
#       <th id="T_a933d_level0_col4" class="col_heading level0 col4" >hemo</th>
#       <th id="T_a933d_level0_col5" class="col_heading level0 col5" >homo</th>
#       <th id="T_a933d_level0_col6" class="col_heading level0 col6" >drugs</th>
#       <th id="T_a933d_level0_col7" class="col_heading level0 col7" >karnof</th>
#       <th id="T_a933d_level0_col8" class="col_heading level0 col8" >oprior</th>
#       <th id="T_a933d_level0_col9" class="col_heading level0 col9" >z30</th>
#       <th id="T_a933d_level0_col10" class="col_heading level0 col10" >preanti</th>
#       <th id="T_a933d_level0_col11" class="col_heading level0 col11" >race</th>
#       <th id="T_a933d_level0_col12" class="col_heading level0 col12" >gender</th>
#       <th id="T_a933d_level0_col13" class="col_heading level0 col13" >str2</th>
#       <th id="T_a933d_level0_col14" class="col_heading level0 col14" >strat</th>
#       <th id="T_a933d_level0_col15" class="col_heading level0 col15" >symptom</th>
#       <th id="T_a933d_level0_col16" class="col_heading level0 col16" >treat</th>
#       <th id="T_a933d_level0_col17" class="col_heading level0 col17" >offtrt</th>
#       <th id="T_a933d_level0_col18" class="col_heading level0 col18" >cd40</th>
#       <th id="T_a933d_level0_col19" class="col_heading level0 col19" >cd420</th>
#       <th id="T_a933d_level0_col20" class="col_heading level0 col20" >cd80</th>
#       <th id="T_a933d_level0_col21" class="col_heading level0 col21" >cd820</th>
#       <th id="T_a933d_level0_col22" class="col_heading level0 col22" >infected</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a933d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a933d_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_a933d_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_a933d_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_a933d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a933d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a933d_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_a933d_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_a933d_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_a933d_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_a933d_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_a933d_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_a933d_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_a933d_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_a933d_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_a933d_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_a933d_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_a933d_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_a933d_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_a933d_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_a933d_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_a933d_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_a933d_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_a933d_row0_col22" class="data row0 col22" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_aids.describe(percentiles=[0, .25, .30, .50, .75, .80, 1]).T.style.background_gradient(cmap = "coolwarm")
# Out:
# <style type="text/css">
# #T_b9c5a_row0_col0, #T_b9c5a_row1_col0, #T_b9c5a_row1_col1, #T_b9c5a_row1_col2, #T_b9c5a_row1_col3, #T_b9c5a_row1_col4, #T_b9c5a_row1_col5, #T_b9c5a_row1_col6, #T_b9c5a_row1_col7, #T_b9c5a_row1_col8, #T_b9c5a_row1_col9, #T_b9c5a_row1_col10, #T_b9c5a_row1_col11, #T_b9c5a_row2_col0, #T_b9c5a_row3_col0, #T_b9c5a_row4_col0, #T_b9c5a_row4_col1, #T_b9c5a_row4_col2, #T_b9c5a_row4_col3, #T_b9c5a_row4_col4, #T_b9c5a_row4_col5, #T_b9c5a_row4_col6, #T_b9c5a_row4_col7, #T_b9c5a_row4_col8, #T_b9c5a_row4_col9, #T_b9c5a_row4_col10, #T_b9c5a_row4_col11, #T_b9c5a_row5_col0, #T_b9c5a_row5_col1, #T_b9c5a_row5_col2, #T_b9c5a_row5_col3, #T_b9c5a_row5_col4, #T_b9c5a_row5_col5, #T_b9c5a_row5_col6, #T_b9c5a_row5_col7, #T_b9c5a_row5_col8, #T_b9c5a_row5_col9, #T_b9c5a_row5_col10, #T_b9c5a_row5_col11, #T_b9c5a_row6_col0, #T_b9c5a_row6_col1, #T_b9c5a_row6_col2, #T_b9c5a_row6_col3, #T_b9c5a_row6_col4, #T_b9c5a_row6_col5, #T_b9c5a_row6_col6, #T_b9c5a_row6_col7, #T_b9c5a_row6_col8, #T_b9c5a_row6_col9, #T_b9c5a_row6_col10, #T_b9c5a_row6_col11, #T_b9c5a_row7_col0, #T_b9c5a_row8_col0, #T_b9c5a_row8_col1, #T_b9c5a_row8_col2, #T_b9c5a_row8_col3, #T_b9c5a_row8_col4, #T_b9c5a_row8_col5, #T_b9c5a_row8_col6, #T_b9c5a_row8_col7, #T_b9c5a_row8_col8, #T_b9c5a_row8_col9, #T_b9c5a_row8_col10, #T_b9c5a_row8_col11, #T_b9c5a_row9_col0, #T_b9c5a_row9_col1, #T_b9c5a_row9_col2, #T_b9c5a_row9_col3, #T_b9c5a_row9_col4, #T_b9c5a_row9_col5, #T_b9c5a_row9_col6, #T_b9c5a_row9_col7, #T_b9c5a_row9_col8, #T_
col11 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b9c5a_row0_col1 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_b9c5a_row0_col2 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_b9c5a_row0_col3, #T_b9c5a_row0_col4 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_b9c5a_row0_col5, #T_b9c5a_row0_col6, #T_b9c5a_row0_col7, #T_b9c5a_row20_col1, #T_b9c5a_row20_col2, #T_b9c5a_row20_col8, #T_b9c5a_row20_col9, #T_b9c5a_row21_col3, #T_b9c5a_row21_col4, #T_b9c5a_row21_col10, #T_b9c5a_row21_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b9c5a_row0_col8 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_b9c5a_row0_col9 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_b9c5a_row0_col10, #T_b9c5a_row0_col11 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_b9c5a_row2_col1, #T_b9c5a_row2_col6 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_b9c5a_row2_col2, #T_b9c5a_row7_col10, #T_b9c5a_row7_col11 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_b9c5a_row2_col3, #T_b9c5a_row2_col4, #T_b9c5a_row7_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_b9c5a_row2_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_b9c5a_row2_col7, #T_b9c5a_row2_col8, #T_b9c5a_row2_col9 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_b9c5a_row2_col10, #T_b9c5a_row2_col11, #T_b9c5a_row14_col3, #T_b9c5a_row14_col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_b9c5a_row3_col1, #T_b9c5a_row3_col7, #T_b9c5a_row7_col9 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_b9c5a_row3_col2, #T_b9c5a_row3_col10, #T_b9c5a_row3_col11 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_b9c5a_row3_col3, #T_b9c5a_row3_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_b9c5a_row3_col5 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_b9c5a_row3_col6, #T_b9c5a_row7_col8 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_b9c5a_row3_col8 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_b9c5a_row3_col9 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_b9c5a_row7_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_b9c5a_row7_col3, #T_b9c5a_row7_col4 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_b9c5a_row7_col5 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_b9c5a_row7_col6 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_b9c5a_row7_col7 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_b9c5a_row10_col1 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_b9c5a_row10_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_b9c5a_row10_col7 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_b9c5a_row10_col8 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_b9c5a_row10_col9 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_b9c5a_row10_col10, #T_b9c5a_row10_col11 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_b9c5a_row18_col1, #T_b9c5a_row19_col7 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_b9c5a_row18_col2 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_b9c5a_row18_col5 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_b9c5a_row18_col6 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_b9c5a_row18_col7, #T_b9c5a_row18_col9 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_b9c5a_row18_col8 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_b9c5a_row18_col10, #T_b9c5a_row18_col11 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_b9c5a_row19_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_b9c5a_row19_col2 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_b9c5a_row19_col3, #T_b9c5a_row19_col4 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_b9c5a_row19_col5 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_b9c5a_row19_col6 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_b9c5a_row19_col8 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_b9c5a_row19_col9 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_b9c5a_row19_col10, #T_b9c5a_row19_col11 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_b9c5a_row20_col3, #T_b9c5a_row20_col4 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_b9c5a_row20_col5 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_b9c5a_row20_col6 {
#   background-co

# %% [markdown]
# Define X variables and our target(y):

# %%
X = df_aids.drop(['infected'],axis=1).values
y = df_aids['infected'].values

# %% [markdown]
# Create the training and test sets for the dataset:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=40)
print(X_train.shape); print(X_test.shape)
# Out:
# (1497, 22)
# (642, 22)

# %% [markdown]
# Balance the dataset:

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state = 14)

X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)

X_train_balanced.shape, y_train_balanced.shape, X_test.shape, y_test.shape
# Out:
# ((2256, 22), (2256,), (642, 22), (642,))

# %% [markdown]
# Visualisation before and after balancing:

# %%
y = pd.Series(y, name="Infected")

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
sns.countplot(x=y, ax=ax1)
ax1.set_title('Before SMOTE')
ax1.set_ylabel('Count')

sns.countplot(x=y_train_balanced, ax=ax2)
ax2.set_title('After SMOTE')
ax2.set_ylabel('Count')

plt.suptitle('Class distribution before and after SMOTE')
plt.tight_layout()
plt.show()

# %% [markdown]
# Scaling the data with MinMaxScaler:

# %%
from sklearn.preprocessing import MinMaxScaler

n_scaler = MinMaxScaler()
X_train_scaled_n_scaler = n_scaler.fit_transform(X_train_balanced)
X_test_scaled_n_scaler = n_scaler.transform(X_test)

# %% [markdown]
# Visualise before and after scaling (MinMaxScaler):

# %%
fig, axes = plt.subplots(2, 1, figsize=(15, 10))

X_train_df = pd.DataFrame(X_train)
X_train_scaled_df = pd.DataFrame(X_train_scaled_n_scaler)

X_train_df.boxplot(ax=axes[0])
axes[0].set_title('Before Scaling (MinMaxScaler)')

X_train_scaled_df.boxplot(ax=axes[1])
axes[1].set_title('After Scaling (MinMaxScaler)')

plt.tight_layout()
plt.show()

# %% [markdown]
# Scaling with StandardScaler:

# %%
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()
X_train_scaled_std_scaler = std_scaler.fit_transform(X_train_balanced)
X_test_scaled_std_scaler = std_scaler.transform(X_test)

# %% [markdown]
# Visualise before and after scaling(Standaed Scaler):

# %%
fig, axes = plt.subplots(2, 1, figsize=(15, 10))

X_train_df = pd.DataFrame(X_train)
X_train_scaled_df = pd.DataFrame(X_train_scaled_std_scaler)

X_train_df.boxplot(ax=axes[0])
axes[0].set_title('Before Scaling (StandardScaler)')

X_train_scaled_df.boxplot(ax=axes[1])
axes[1].set_title('After Scaling (StandardScaler)')

plt.tight_layout()
plt.show()

# %%
from sklearn.feature_selection import SelectKBest, f_classif
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

selector = SelectKBest(f_classif, k=5)
X_new = selector.fit_transform(X_train_scaled_std_scaler, y_train_balanced)

X_train_balanced_df = pd.DataFrame(X_train_balanced, columns=[f'feature_{i}' for i in range(X_train_balanced.shape[1])])

selected_features = pd.DataFrame(selector.inverse_transform(X_new),
                                    index=X_train_balanced_df.index,
                                    columns=X_train_balanced_df.columns)

selected_columns = selected_features.columns[selected_features.var() != 0]
selected_indices = np.where(selected_features.var() != 0)[0]

X_train_selected = X_train_balanced[:, selected_indices]
X_test_selected = X_test[:, selected_indices]

X_train_selected.shape, X_test_selected.shape
# Out:
# ((2256, 5), (642, 5))

# %% [markdown]
# Method to print the scores for each model:

# %%
from sklearn.metrics import ConfusionMatrixDisplay, RocCurveDisplay

def print_scores(model, test_data, lr_accuracy, lr_precision, lr_recall, lr_f1_score, lr_cm):
    print(f'Accuracy: {lr_accuracy}')
    print(f'Precision: {lr_precision}')
    print(f'Recall: {lr_recall}')
    print(f'F1 Score: {lr_f1_score}')

    disp = ConfusionMatrixDisplay(confusion_matrix=lr_cm, display_labels=np.unique(y_test))
    disp.plot(cmap='Blues', values_format='d')
    plt.title('Confusion Matrix (Logistic Regression)')
    plt.show()

    RocCurveDisplay.from_estimator(model, test_data, y_test)
    plt.title('ROC Curve (Logistic Regression)')
    plt.show()

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ### Initial Model

# %% [markdown]
# Testing initial score with feature selection:

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(random_state=42)
lr.fit(X_train_selected, y_train_balanced)
lr_pred_initial = lr.predict(X_test_selected)

lr_accuracy_initial = metrics.accuracy_score(y_test, lr_pred_initial)
lr_precision_initial = metrics.precision_score(y_test, lr_pred_initial)
lr_recall_initial = metrics.recall_score(y_test, lr_pred_initial)
lr_f1_score_initial = metrics.f1_score(y_test, lr_pred_initial)
lr_cm_initial = metrics.confusion_matrix(y_test, lr_pred_initial)

print_scores(lr, X_test_selected, lr_accuracy_initial, lr_precision_initial, lr_recall_initial, lr_f1_score_initial, lr_cm_initial)
# Out:
# Accuracy: 0.8582554517133957
# Precision: 0.6564102564102564
# Recall: 0.8421052631578947
# F1 Score: 0.7377521613832853

# %% [markdown]
# Test initial score with MinMaxScaler:

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import ConfusionMatrixDisplay, RocCurveDisplay

lr = LogisticRegression(random_state=42)
lr.fit(X_train_scaled_n_scaler, y_train_balanced)
lr_pred_initial = lr.predict(X_test_scaled_n_scaler)
lr_accuracy_initial = metrics.accuracy_score(y_test, lr_pred_initial)
lr_precision_initial = metrics.precision_score(y_test, lr_pred_initial)
lr_recall_initial = metrics.recall_score(y_test, lr_pred_initial)
lr_f1_score_initial = metrics.f1_score(y_test, lr_pred_initial)
lr_cm_initial = metrics.confusion_matrix(y_test, lr_pred_initial)

print_scores(lr, X_test_scaled_n_scaler, lr_accuracy_initial, lr_precision_initial, lr_recall_initial, lr_f1_score_initial, lr_cm_initial)
# Out:
# Accuracy: 0.8691588785046729
# Precision: 0.6868131868131868
# Recall: 0.8223684210526315
# F1 Score: 0.7485029940119761

# %% [markdown]
# Test initial scores with StandardScaler:

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import ConfusionMatrixDisplay, RocCurveDisplay

lr = LogisticRegression(random_state=42)
lr.fit(X_train_scaled_std_scaler, y_train_balanced)
lr_pred = lr.predict(X_test_scaled_std_scaler)
lr_accuracy = metrics.accuracy_score(y_test, lr_pred)
lr_precision = metrics.precision_score(y_test, lr_pred)
lr_recall = metrics.recall_score(y_test, lr_pred)
lr_f1_score = metrics.f1_score(y_test, lr_pred)
lr_cm = metrics.confusion_matrix(y_test, lr_pred)

print_scores(lr, X_test_scaled_std_scaler, lr_accuracy, lr_precision, lr_recall, lr_f1_score, lr_cm)
# Out:
# Accuracy: 0.8644859813084113
# Precision: 0.6737967914438503
# Recall: 0.8289473684210527
# F1 Score: 0.7433628318584071

# %% [markdown]
# Initial test results:
#
# | Metric      | With Selected Features | With MinMaxScaler only | With StandardScaler only |   |
# |-------------|------------------------|------------------------|--------------------------|---|
# | Accuracy:   | 0.8582554517133957     | 0.8691588785046729     | 0.8644859813084113       |   |
# | Precision:  | 0.6564102564102564     | 0.6868131868131868     | 0.6737967914438503       |   |
# | Recall:     | 0.8421052631578947     | 0.8223684210526315     | 0.8289473684210527       |   |
# | F1 Score:   | 0.7377521613832853     | 0.7485029940119761     | 0.7433628318584071       |   |

# %% [markdown]
# ### Hyperparameter Tuning (GridSearchCV)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear', 'saga'],
    'max_iter': [10000]
}

lr = LogisticRegression(random_state=42)
lr_cv = GridSearchCV(lr, param_grid, cv=5)

# %% [markdown]
# Fit with MinMaxScaler:

# %%
lr_cv.fit(X_train_scaled_n_scaler, y_train_balanced)

print(f'Best Parameters: {lr_cv.best_params_}')
print(f'Best Score: {lr_cv.best_score_}')
# Out:
# Best Parameters: {'C': 1, 'max_iter': 10000, 'penalty': 'l1', 'solver': 'liblinear'}
# Best Score: 0.8413182112512999

# %% [markdown]
# Fit with StandardScaler

# %%
lr_cv.fit(X_train_scaled_std_scaler, y_train_balanced)

print(f'Best Parameters: {lr_cv.best_params_}')
print(f'Best Score: {lr_cv.best_score_}')
# Out:
# Best Parameters: {'C': 0.1, 'max_iter': 10000, 'penalty': 'l1', 'solver': 'saga'}
# Best Score: 0.8444234052155485

# %% [markdown]
# Test hyperparameter tuning with MinMaxSclaler

# %%
lr = LogisticRegression(random_state=42, C=1, max_iter=10000, penalty='l1', solver='liblinear')
lr.fit(X_train_scaled_n_scaler, y_train_balanced)
lr_pred = lr.predict(X_test_scaled_n_scaler)

lr_accuracy = metrics.accuracy_score(y_test, lr_pred)
lr_precision = metrics.precision_score(y_test, lr_pred)
lr_recall = metrics.recall_score(y_test, lr_pred)
lr_f1_score = metrics.f1_score(y_test, lr_pred)
lr_cm = metrics.confusion_matrix(y_test, lr_pred)

print_scores(lr, X_test_scaled_n_scaler, lr_accuracy, lr_precision, lr_recall, lr_f1_score, lr_cm)
# Out:
# Accuracy: 0.8722741433021807
# Precision: 0.6923076923076923
# Recall: 0.8289473684210527
# F1 Score: 0.7544910179640718

# %% [markdown]
# Test hyperparameter tuning with StandardScaler:

# %%
lr = LogisticRegression(random_state=42, C=0.1, max_iter=10000, penalty='l1', solver='saga')
lr.fit(X_train_scaled_std_scaler, y_train_balanced)
lr_pred = lr.predict(X_test_scaled_std_scaler)

lr_accuracy = metrics.accuracy_score(y_test, lr_pred)
lr_precision = metrics.precision_score(y_test, lr_pred)
lr_recall = metrics.recall_score(y_test, lr_pred)
lr_f1_score = metrics.f1_score(y_test, lr_pred)
lr_cm = metrics.confusion_matrix(y_test, lr_pred)

print_scores(lr, X_test_scaled_std_scaler, lr_accuracy, lr_precision, lr_recall, lr_f1_score, lr_cm)
# Out:
# Accuracy: 0.8785046728971962
# Precision: 0.7032967032967034
# Recall: 0.8421052631578947
# F1 Score: 0.7664670658682635

# %% [markdown]
# ### Final Model
#
#  Model: Logistic Regression
#
#  Scaler: Standard Scaler
#
#  Hyperparameters:
# - `random_state`: 42
# - `C`: 0.1
# - `penalty`: 'l1'
# - `solver`: 'saga'
#
# #### Performance Comparison:
# | **Metric**   | **Initial** | **Final**  |
# |--------------|-------------|------------|
# | **Accuracy** | 0.869       | 0.879      |
# | **Precision**| 0.687       | 0.703      |
# | **Recall**   | 0.822       | 0.842      |
# | **F1 Score** | 0.749       | 0.766      |

# %%
lr_final = LogisticRegression(random_state=42, C=0.1, penalty='l1', solver='saga')
lr_final.fit(X_train_scaled_std_scaler, y_train_balanced)
lr_pred_final = lr.predict(X_test_scaled_std_scaler)

lr_accuracy_final = metrics.accuracy_score(y_test, lr_pred_final)
lr_precision_final = metrics.precision_score(y_test, lr_pred_final)
lr_recall_final = metrics.recall_score(y_test, lr_pred_final)
lr_f1_score_final = metrics.f1_score(y_test, lr_pred_final)
lr_cm_final = metrics.confusion_matrix(y_test, lr_pred_final)

print_scores(lr_final, X_test_scaled_std_scaler, lr_accuracy_final, lr_precision_final, lr_recall_final, lr_f1_score_final, lr_cm_final)
# Out:
# Accuracy: 0.8785046728971962
# Precision: 0.7032967032967034
# Recall: 0.8421052631578947
# F1 Score: 0.7664670658682635

# %%
print(f'Final Results: Logistic Regression')
print(f'Accuracy: {lr_accuracy_initial} -> {lr_accuracy_final}')
print(f'Precision: {lr_precision_initial} -> {lr_precision_final}')
print(f'Recall: {lr_recall_initial} -> {lr_recall_final}')
print(f'F1 Score: {lr_f1_score_initial} -> {lr_f1_score_final}')


fig, ax = plt.subplots(figsize=(10, 5))

metrics_list = [lr_accuracy_initial, lr_precision_initial, lr_recall_initial, lr_f1_score_initial]
metrics_list_final = [lr_accuracy, lr_precision, lr_recall, lr_f1_score]
metrics_names = ['Accuracy', 'Precision', 'Recall', 'F1 Score']

x = np.arange(len(metrics_list))
bar_width = 0.35

ax.bar(x, metrics_list, bar_width, label='Initial Model')
ax.bar(x + bar_width, metrics_list_final, bar_width, label='Final Model')

ax.set_xticks(x + bar_width / 2)
ax.set_xticklabels(metrics_names)
ax.set_title('Metrics Comparison')
ax.legend()
plt.show()
# Out:
# Final Results: Logistic Regression
# Accuracy: 0.8691588785046729 -> 0.8785046728971962
# Precision: 0.6868131868131868 -> 0.7032967032967034
# Recall: 0.8223684210526315 -> 0.8421052631578947
# F1 Score: 0.7485029940119761 -> 0.7664670658682635

# %% [markdown]
# ## Support Vector Machine (SVM)

# %% [markdown]
# ### Initial Model

# %% [markdown]
# Testing with feature selection:

# %%
from sklearn.svm import SVC

svm = SVC(random_state=42)
svm.fit(X_train_selected, y_train_balanced)

svm_pred_initial = svm.predict(X_test_selected)

svm_accuracy_initial = metrics.accuracy_score(y_test, svm_pred_initial)
svm_precision_initial = metrics.precision_score(y_test, svm_pred_initial)
svm_recall_initial = metrics.recall_score(y_test, svm_pred_initial)
svm_f1_score_initial = metrics.f1_score(y_test, svm_pred_initial)
svm_cm_initial = metrics.confusion_matrix(y_test, svm_pred_initial)

print_scores(svm, X_test_selected, svm_accuracy_initial, svm_precision_initial, svm_recall_initial, svm_f1_score_initial, svm_cm_initial)
# Out:
# Accuracy: 0.8286604361370716
# Precision: 0.5875
# Recall: 0.9276315789473685
# F1 Score: 0.7193877551020408

# %% [markdown]
# Testing with MinMaxScaler:

# %%
from sklearn.svm import SVC

svm = SVC(random_state=42)
svm.fit(X_train_scaled_n_scaler, y_train_balanced)

svm_pred = svm.predict(X_test_scaled_n_scaler)

svm_accuracy = metrics.accuracy_score(y_test, svm_pred)
svm_precision = metrics.precision_score(y_test, svm_pred)
svm_recall = metrics.recall_score(y_test, svm_pred)
svm_f1_score = metrics.f1_score(y_test, svm_pred)
svm_cm = metrics.confusion_matrix(y_test, svm_pred)

print_scores(svm, X_test_scaled_std_scaler, svm_accuracy, svm_precision, svm_recall, svm_f1_score, svm_cm)
# Out:
# Accuracy: 0.8862928348909658
# Precision: 0.7762237762237763
# Recall: 0.7302631578947368
# F1 Score: 0.752542372881356

# %% [markdown]
# Testing with StandardScaler:

# %%
from sklearn.svm import SVC

svm = SVC(random_state=42)
svm.fit(X_train_scaled_std_scaler, y_train_balanced)

svm_pred = svm.predict(X_test_scaled_std_scaler)

svm_accuracy = metrics.accuracy_score(y_test, svm_pred)
svm_precision = metrics.precision_score(y_test, svm_pred)
svm_recall = metrics.recall_score(y_test, svm_pred)
svm_f1_score = metrics.f1_score(y_test, svm_pred)
svm_cm = metrics.confusion_matrix(y_test, svm_pred)

print_scores(svm, X_test_scaled_std_scaler, svm_accuracy, svm_precision, svm_recall, svm_f1_score, svm_cm)
# Out:
# Accuracy: 0.8956386292834891
# Precision: 0.7931034482758621
# Recall: 0.756578947368421
# F1 Score: 0.7744107744107744

# %% [markdown]
# ### Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'class_weight': ['balanced', None],
    'gamma': ['scale', 'auto']
}

svm = SVC(random_state=42)
svm_cv = GridSearchCV(svm, param_grid, cv=5)

# %% [markdown]
# Tuning with MinMaxScaler:

# %%
svm_cv.fit(X_train_scaled_n_scaler, y_train_balanced)

print(f'Best Parameters: {svm_cv.best_params_}')
print(f'Best Score: {svm_cv.best_score_}')
# Out:
# Best Parameters: {'C': 10, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'rbf'}
# Best Score: 0.9069530836096776

# %% [markdown]
# Tuning with StandardScaler:

# %%
svm_cv.fit(X_train_scaled_std_scaler, y_train_balanced)

print(f'Best Parameters: {svm_cv.best_params_}')
print(f'Best Score: {svm_cv.best_score_}')
# Out:
# Best Parameters: {'C': 10, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'rbf'}
# Best Score: 0.917576477051979

# %% [markdown]
# Testing the model:

# %%
svm = SVC(random_state=42, C=10, class_weight='balanced', gamma='scale', kernel='rbf')

# %% [markdown]
# Test with MinMaxScaled:

# %%
svm.fit(X_train_scaled_n_scaler, y_train_balanced)
svm_pred = svm.predict(X_test_scaled_n_scaler)

svm_accuracy = metrics.accuracy_score(y_test, svm_pred)
svm_precision = metrics.precision_score(y_test, svm_pred)
svm_recall = metrics.recall_score(y_test, svm_pred)
svm_f1_score = metrics.f1_score(y_test, svm_pred)
svm_cm = metrics.confusion_matrix(y_test, svm_pred)

print_scores(svm, X_test_scaled_n_scaler, svm_accuracy, svm_precision, svm_recall, svm_f1_score, svm_cm)
# Out:
# Accuracy: 0.8925233644859814
# Precision: 0.816793893129771
# Recall: 0.7039473684210527
# F1 Score: 0.7561837455830389

# %% [markdown]
# Test with StandardScaler:

# %%
svm.fit(X_train_scaled_std_scaler, y_train_balanced)
svm_pred = svm.predict(X_test_scaled_std_scaler)

svm_accuracy = metrics.accuracy_score(y_test, svm_pred)
svm_precision = metrics.precision_score(y_test, svm_pred)
svm_recall = metrics.recall_score(y_test, svm_pred)
svm_f1_score = metrics.f1_score(y_test, svm_pred)
svm_cm = metrics.confusion_matrix(y_test, svm_pred)

print_scores(svm, X_test_scaled_std_scaler, svm_accuracy, svm_precision, svm_recall, svm_f1_score, svm_cm)
# Out:
# Accuracy: 0.867601246105919
# Precision: 0.7342657342657343
# Recall: 0.6907894736842105
# F1 Score: 0.711864406779661

# %% [markdown]
# ### Final Model: Support Vector Machine (SVM)
#
# #### Model Parameters:
# - `random_state`: 42
# - `C`: 10
# - `class_weight`: 'balanced'
# - `gamma`: 'scale'
# - `kernel`: 'rbf'
#
# #### Performance Comparison:
# | **Metric**   | **Initial** | **Final**  |
# |--------------|-------------|------------|
# | **Accuracy** | 0.829       | 0.893      |
# | **Precision**| 0.5875      | 0.817      |
# | **Recall**   | 0.928       | 0.704      |
# | **F1 Score** | 0.719       | 0.756      |

# %%
svm.fit(X_train_scaled_n_scaler, y_train_balanced)
svm_pred = svm.predict(X_test_scaled_n_scaler)

svm_accuracy_final = metrics.accuracy_score(y_test, svm_pred)
svm_precision_final = metrics.precision_score(y_test, svm_pred)
svm_recall_final = metrics.recall_score(y_test, svm_pred)
svm_f1_score_final = metrics.f1_score(y_test, svm_pred)
svm_cm_final = metrics.confusion_matrix(y_test, svm_pred)

print_scores(svm, X_test_scaled_n_scaler, svm_accuracy_final, svm_precision_final, svm_recall_final, svm_f1_score_final, svm_cm_final)
# Out:
# Accuracy: 0.8925233644859814
# Precision: 0.816793893129771
# Recall: 0.7039473684210527
# F1 Score: 0.7561837455830389

# %%
#compare the initial and final results
print(f'Final Results: SVM')
print(f'Accuracy: {svm_accuracy_initial} -> {svm_accuracy_final}')
print(f'Precision: {svm_precision_initial} -> {svm_precision_final}')
print(f'Recall: {svm_recall_initial} -> {svm_recall_final}')
print(f'F1 Score: {svm_f1_score_initial} -> {svm_f1_score_final}')

fig, ax = plt.subplots(figsize=(10, 5))

metrics_list = [svm_accuracy_initial, svm_precision_initial, svm_recall_initial, svm_f1_score_initial]
metrics_list_final = [svm_accuracy_final, svm_precision_final, svm_recall_final, svm_f1_score_final]
metrics_names = ['Accuracy', 'Precision', 'Recall', 'F1 Score']

x = np.arange(len(metrics_list))
bar_width = 0.35

ax.bar(x, metrics_list, bar_width, label='Initial Model')
ax.bar(x + bar_width, metrics_list_final, bar_width, label='Final Model')

ax.set_xticks(x + bar_width / 2)
ax.set_xticklabels(metrics_names)
ax.set_title('Metrics Comparison')
ax.legend()
plt.show()
# Out:
# Final Results: SVM
# Accuracy: 0.8286604361370716 -> 0.8925233644859814
# Precision: 0.5875 -> 0.816793893129771
# Recall: 0.9276315789473685 -> 0.7039473684210527
# F1 Score: 0.7193877551020408 -> 0.7561837455830389

# %%
#catboost
from catboost import CatBoostClassifier

cat = CatBoostClassifier(random_state=42, verbose=0)
cat.fit(X_train_scaled_n_scaler, y_train_balanced)
cat_pred_initial = cat.predict(X_test_scaled_n_scaler)
cat_accuracy_initial = metrics.accuracy_score(y_test, cat_pred_initial)
cat_precision_initial = metrics.precision_score(y_test, cat_pred_initial)
cat_recall_initial = metrics.recall_score(y_test, cat_pred_initial)
cat_f1_score_initial = metrics.f1_score(y_test, cat_pred_initial)

cat_cm_initial = metrics.confusion_matrix(y_test, cat_pred_initial)

print(f'Accuracy: {cat_accuracy_initial}')
print(f'Precision: {cat_precision_initial}')
print(f'Recall: {cat_recall_initial}')
print(f'F1 Score: {cat_f1_score_initial}')


disp = ConfusionMatrixDisplay(confusion_matrix=cat_cm_initial, display_labels=np.unique(y_test))
disp.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix (CatBoost)')
plt.show()

RocCurveDisplay.from_estimator(cat, X_test_scaled_n_scaler, y_test)
plt.title('ROC Curve (CatBoost)')
plt.show()
# Out:
# Accuracy: 0.9034267912772586
# Precision: 0.8125
# Recall: 0.7697368421052632
# F1 Score: 0.7905405405405406

# %%
#tune hyperparameters for CatBoost
param_grid = {
    'learning_rate': [0.01, 0.1, 1],
    'depth': [4, 6, 8],
}

cat = CatBoostClassifier(random_state=42, verbose=0)
cat_cv = GridSearchCV(cat, param_grid, cv=5)

cat_cv.fit(X_train_scaled_n_scaler, y_train_balanced)

print(f'Best Parameters: {cat_cv.best_params_}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[189], line 10
#       7 cat = CatBoostClassifier(random_state=42, verbose=0)
#       8 cat_cv = GridSearchCV(cat, param_grid, cv=5)
# ---> 10 cat_cv.fit(X_train_scaled_n_scaler, y_train_balanced)
#      12 print(f'Best Parameters: {cat_cv.best_params_}')
#
# File c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1018, in BaseSearchCV.fit(self, X, y, **params)
#    1012     results = self._format_results(
#    1013         all_candidate_params, n_splits, all_out, all_more_results
#    1014     )
#    1016     return results
# -> 1018 self._run_search(evaluate_candidates)
#    1020 # multimetric is determined here because in the case of a callable
#    1021 # self.scoring the return type is only known after calling
#    1022 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1572, in GridSearchCV._run_search(self, evaluate_candidates)
#    1570 def _run_search(self, evaluate_candidates):
#    1571     """Search all candidates in param_grid"""
# -> 1572     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:964, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     956 if self.verbose > 0:
#     957     print(
#     958         "Fitting {0} folds for each of {1} candidates,"
#     959         " totalling {2} fits".format(
#     960             n_splits, n_candidates, n_candidates * n_splits
#     961         )
#     962     )
# --> 964 out = parallel(
#     965     delayed(_fit_and_score)(
#     966         clone(base_estimator),
#     967         X,
#     968         y,
#     969         train=train,
#     970         test=test,
#     971         parameters=parameters,
#     972         split_progress=(split_idx, n_splits),
#     973         candidate_progress=(cand_idx, n_candidates),
#     974         **fit_and_score_kwargs,
#     975     )
#     976     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     977         enumerate(candidate_params),
#     978         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     979     )
#     980 )
#     982 if len(out) < 1:
#     983     raise ValueError(
#     984         "No fits were performed. "
#     985         "Was the CV iterator empty? "
#     986         "Were there no candidates?"
#     987     )
#
# File c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File c:\Users\bwelo\anaconda3\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File c:\Users\bwelo\anaconda3\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:888, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     886         estimator.fit(X_train, **fit_params)
#     887     else:
# --> 888         estimator.fit(X_train, y_train, **fit_params)
#     890 except Exception:
#     891     # Note fit time as time until error
#     892     fit_time = time.time() - start_time
#
# File c:\Users\bwelo\anaconda3\Lib\site-packages\catboost\core.py:5245, in CatBoostClassifier.fit(self, X, y, cat_features, text_features, embedding_features, graph, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5242 if 'loss_function' in params:
#    5243     CatBoostClassifier._check_is_compatible_loss(params['loss_function'])
# -> 5245 self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline, use_best_model,
#    5246           eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period,
#    5247           silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5248 return self
#
# File c:\Users\bwelo\anaconda3\Lib\site-packages\catboost\core.py:2410, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, graph, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2407 allow_clear_pool = train_params["allow_clear_pool"]
#    2409 with plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2410     self._train(
#    2411         train_pool,
#    2412         train_params["eval_sets"],
#    2413         params,
#    2414         allow_clear_pool,
#    2415         train_params["init_model"]
#    2416     )
#    2418 # Have property feature_importance possibly set
#    2419 loss = self._object._get_loss_function_name()
#
# File c:\Users\bwelo\anaconda3\Lib\site-packages\catboost\core.py:1790, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1789 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1790     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1791     self._set_trained_model_attributes()
#
# File _catboost.pyx:5017, in _catboost._CatBoost._train()
#
# File _catboost.pyx:5066, in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
#using optuna for hyperparameter tuning
import optuna
from catboost import CatBoostClassifier

def objective(trial):

    learning_rate = trial.suggest_float('learning_rate', 0.01, 1)
    depth = trial.suggest_int('depth', 4, 8)

    cat = CatBoostClassifier(random_state=42, verbose=0, learning_rate=learning_rate, depth=depth)
    cat.fit(X_train_scaled_n_scaler, y_train_balanced)
    cat_pred = cat.predict(X_test_scaled_n_scaler)
    cat_accuracy = metrics.accuracy_score(y_test, cat_pred)

    return cat_accuracy

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2024-11-23 16:59:54,711] A new study created in memory with name: no-name-0adc35e6-9c0a-4774-a1ba-2365c289a000
# [I 2024-11-23 16:59:58,217] Trial 0 finished with value: 0.883177570093458 and parameters: {'learning_rate': 0.4794978290303354, 'depth': 4}. Best is trial 0 with value: 0.883177570093458.
# [I 2024-11-23 17:00:07,316] Trial 1 finished with value: 0.8894080996884736 and parameters: {'learning_rate': 0.07351888392941251, 'depth': 7}. Best is trial 1 with value: 0.8894080996884736.
# [I 2024-11-23 17:00:12,442] Trial 2 finished with value: 0.8909657320872274 and parameters: {'learning_rate': 0.21707784748370915, 'depth': 5}. Best is trial 2 with value: 0.8909657320872274.
# [I 2024-11-23 17:00:17,105] Trial 3 finished with value: 0.8940809968847352 and parameters: {'learning_rate': 0.3476742624577311, 'depth': 5}. Best is trial 3 with value: 0.8940809968847352.
# [I 2024-11-23 17:00:37,337] Trial 4 finished with value: 0.8956386292834891 and parameters: {'learning_rate': 0.0844326575445853, 'depth': 8}. Best is trial 4 with value: 0.8956386292834891.
# [I 2024-11-23 17:00:43,974] Trial 5 finished with value: 0.8940809968847352 and parameters: {'learning_rate': 0.05538160536799626, 'depth': 6}. Best is trial 4 with value: 0.8956386292834891.
# [I 2024-11-23 17:00:49,106] Trial 6 finished with value: 0.8925233644859814 and parameters: {'learning_rate': 0.31273784102152424, 'depth': 5}. Best is trial 4 with value: 0.8956386292834891.
# [I 2024-11-23 17:01:03,207] Trial 7 finished with value: 0.897196261682243 and parameters: {'learning_rate': 0.47807260479479496, 'depth': 8}. Best is trial 7 with value: 0.897196261682243.
# [I 2024-11-23 17:01:11,029] Trial 8 finished with value: 0.8878504672897196 and parameters: {'learning_rate': 0.7826193854326926, 'depth': 7}. Best is trial 7 with value: 0.897196261682243.
# [I 2024-11-23 17:01:15,555] Trial 9 finished with value: 0.8894080996884736 and parameters: {'learning_rate': 0.09057679071962367, 'depth': 5}. Best is trial 7 with value: 0.897196261682243.
# [I 2024-11-23 17:01:29,158] Trial 10 finished with value: 0.8894080996884736 and parameters: {'learning_rate': 0.753092369716709, 'depth': 8}. Best is trial 7 with value: 0.897196261682243.
# [I 2024-11-23 17:01:41,852] Trial 11 finished with value: 0.8847352024922118 and parameters: {'learning_rate': 0.94961554968659, 'depth': 8}. Best is trial 7 with value: 0.897196261682243.
# [I 2024-11-23 17:01:54,989] Trial 12 finished with value: 0.8862928348909658 and parameters: {'learning_rate': 0.5775732435390417, 'depth': 8}. Best is trial 7 with value: 0.897196261682243.
# [I 2024-11-23 17:02:03,211] Trial 13 finished with value: 0.8862928348909658 and parameters: {'learning_rate': 0.4648432917013994, 'depth': 7}. Best is trial 7 with value: 0.897196261682243.
# [I 2024-11-23 17:02:16,990] Trial 14 finished with value: 0.8847352024922118 and parameters: {'learning_rate': 0.6005537769347717, 'depth': 8}. Best is trial 7 with value: 0.897196261682243.
# [I 2024-11-23 17:02:25,701] Trial 15 finished with value: 0.8909657320872274 and parameters: {'learning_rate': 0.23017085494982142, 'depth': 7}. Best is trial 7 with value: 0.897196261682243.
# [I 2024-11-23 17:02:31,541] Trial 16 finished with value: 0.881619937694704 and parameters: {'learning_rate': 0.7227503248899996, 'depth': 6}. Best is trial 7 with value: 0.897196261682243.
# [I 2024-11-23 17:02:45,117] Trial 17 finished with value: 0.8738317757009346 and parameters: {'learning_rate': 0.9897097855955735, 'depth': 8}. Best is trial 7 with value: 0.897196261682243.
# [I 2024-11-23 17:02:50,826] Trial 18 finished with value: 0.8862928348909658 and parameters: {'learning_rate': 0
 'depth': 5}. Best is trial 80 with value: 0.9112149532710281.
# [I 2024-11-23 17:12:10,251] Trial 91 finished with value: 0.9080996884735203 and parameters: {'learning_rate': 0.014156872437417497, 'depth': 5}. Best is trial 80 with value: 0.9112149532710281.
# [I 2024-11-23 17:12:14,649] Trial 92 finished with value: 0.9080996884735203 and parameters: {'learning_rate': 0.010426551689774393, 'depth': 5}. Best is trial 80 with value: 0.9112149532710281.
# [I 2024-11-23 17:12:19,029] Trial 93 finished with value: 0.8925233644859814 and parameters: {'learning_rate': 0.07603974095423399, 'depth': 5}. Best is trial 80 with value: 0.9112149532710281.
# [I 2024-11-23 17:12:22,603] Trial 94 finished with value: 0.8878504672897196 and parameters: {'learning_rate': 0.042446339655642894, 'depth': 4}. Best is trial 80 with value: 0.9112149532710281.
# [I 2024-11-23 17:12:26,450] Trial 95 finished with value: 0.8753894080996885 and parameters: {'learning_rate': 0.8893008774229879, 'depth': 5}. Best is trial 80 with value: 0.9112149532710281.
# [I 2024-11-23 17:12:30,731] Trial 96 finished with value: 0.8909657320872274 and parameters: {'learning_rate': 0.0574495889559948, 'depth': 5}. Best is trial 80 with value: 0.9112149532710281.
# [I 2024-11-23 17:12:35,012] Trial 97 finished with value: 0.8894080996884736 and parameters: {'learning_rate': 0.08590718569081862, 'depth': 5}. Best is trial 80 with value: 0.9112149532710281.
# [I 2024-11-23 17:12:39,396] Trial 98 finished with value: 0.897196261682243 and parameters: {'learning_rate': 0.030064340552976597, 'depth': 5}. Best is trial 80 with value: 0.9112149532710281.
# [I 2024-11-23 17:12:43,707] Trial 99 finished with value: 0.9065420560747663 and parameters: {'learning_rate': 0.012107514893773798, 'depth': 5}. Best is trial 80 with value: 0.9112149532710281.

# %%
from catboost import CatBoostClassifier
#{'learning_rate': 0.011657540313006571, 'depth': 5}

cat = CatBoostClassifier(random_state=42, verbose=0, learning_rate=0.011657540313006571, depth=5)
cat.fit(X_train_scaled_n_scaler, y_train_balanced)
cat_pred = cat.predict(X_test_scaled_n_scaler)
cat_accuracy = metrics.accuracy_score(y_test, cat_pred)
cat_precision = metrics.precision_score(y_test, cat_pred)
cat_recall = metrics.recall_score(y_test, cat_pred)
cat_f1_score = metrics.f1_score(y_test, cat_pred)

cat_cm = metrics.confusion_matrix(y_test, cat_pred)

print(f'Accuracy: {cat_accuracy}')
print(f'Precision: {cat_precision}')
print(f'Recall: {cat_recall}')
print(f'F1 Score: {cat_f1_score}')

disp = ConfusionMatrixDisplay(confusion_matrix=cat_cm, display_labels=np.unique(y_test))
disp.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix (CatBoost)')
plt.show()

RocCurveDisplay.from_estimator(cat, X_test_scaled_n_scaler, y_test)
plt.title('ROC Curve (CatBoost)')
# Out:
# Accuracy: 0.9112149532710281
# Precision: 0.8145695364238411
# Recall: 0.8092105263157895
# F1 Score: 0.8118811881188119
# Text(0.5, 1.0, 'ROC Curve (CatBoost)')

# %%
#final model
cat_final = CatBoostClassifier(random_state=42, verbose=0, **cat_cv.best_params_)
cat_final.fit(X_train_scaled_n_scaler, y_train_balanced)
cat_pred_final = cat_final.predict(X_test_scaled_n_scaler)
cat_accuracy_final = metrics.accuracy_score(y_test, cat_pred_final)
cat_precision_final = metrics.precision_score(y_test, cat_pred_final)
cat_recall_final = metrics.recall_score(y_test, cat_pred_final)
cat_f1_score_final = metrics.f1_score(y_test, cat_pred_final)
cat_cm_final = metrics.confusion_matrix(y_test, cat_pred_final)

print(f'Accuracy: {cat_accuracy_final}')
print(f'Precision: {cat_precision_final}')
print(f'Recall: {cat_recall_final}')
print(f'F1 Score: {cat_f1_score_final}')

disp = ConfusionMatrixDisplay(confusion_matrix=cat_cm_final, display_labels=np.unique(y_test))
disp.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix (CatBoost - Final)')
plt.show()

RocCurveDisplay.from_estimator(cat, X_test_scaled_n_scaler, y_test)
plt.title('ROC Curve (CatBoost - Final)')

# %%
#compare the two models
print(f'Final Results: CatBoost')
print(f'Accuracy: {cat_accuracy_initial} -> {cat_accuracy_final}')
print(f'Precision: {cat_precision_initial} -> {cat_precision_final}')
print(f'Recall: {cat_recall_initial} -> {cat_recall_final}')
print(f'F1 Score: {cat_f1_score_initial} -> {cat_f1_score_final}')

#plot metrics on same graph
fig, ax = plt.subplots(figsize=(10, 5))

metrics_list = [cat_accuracy_initial, cat_precision_initial, cat_recall_initial, cat_f1_score_initial]
metrics_list_final = [cat_accuracy, cat_precision, cat_recall, cat_f1_score]
metrics_names = ['Accuracy', 'Precision', 'Recall', 'F1 Score']

x = np.arange(len(metrics_list))
bar_width = 0.35

ax.bar(x, metrics_list, bar_width, label='Initial Model')
ax.bar(x + bar_width, metrics_list_final, bar_width, label='Final Model')

ax.set_xticks(x + bar_width / 2)
ax.set_xticklabels(metrics_names)
ax.set_title('Metrics Comparison')
ax.legend()
plt.show()

# %%
#neural network
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(random_state=42)
mlp.fit(X_train_scaled_n_scaler, y_train_balanced)
mlp_pred_initial = mlp.predict(X_test_scaled_n_scaler)
mlp_accuracy_initial = metrics.accuracy_score(y_test, mlp_pred_initial)
mlp_precision_initial = metrics.precision_score(y_test, mlp_pred_initial)
mlp_recall_initial = metrics.recall_score(y_test, mlp_pred_initial)
mlp_f1_score_initial = metrics.f1_score(y_test, mlp_pred_initial)
mlp_cm_initial = metrics.confusion_matrix(y_test, mlp_pred_initial)

print(f'Accuracy: {mlp_accuracy_initial}')
print(f'Precision: {mlp_precision_initial}')
print(f'Recall: {mlp_recall_initial}')
print(f'F1 Score: {mlp_f1_score_initial}')

disp = ConfusionMatrixDisplay(confusion_matrix=mlp_cm_initial, display_labels=np.unique(y_test))
disp.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix (MLP)')
plt.show()

RocCurveDisplay.from_estimator(mlp, X_test_scaled_n_scaler, y_test)
plt.title('ROC Curve (MLP)')
# Out:
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Accuracy: 0.9065420560747663
# Precision: 0.7911392405063291
# Recall: 0.8223684210526315
# F1 Score: 0.8064516129032258
# Text(0.5, 1.0, 'ROC Curve (MLP)')

# %%
#tune hyperparameters for MLP
param_grid = {
    'hidden_layer_sizes': [(50,), (100,), (200,)],
    'activation': ['relu', 'tanh', 'logistic'],
}

mlp = MLPClassifier(random_state=42)
mlp_cv = GridSearchCV(mlp, param_grid, cv=5)

mlp_cv.fit(X_train_scaled_n_scaler, y_train_balanced)

print(f'Best Parameters: {mlp_cv.best_params_}')
# Out:
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Best Parameters: {'activation': 'relu', 'hidden_layer_sizes': (200,)}
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
mlp = MLPClassifier(random_state=42, **mlp_cv.best_params_)
mlp.fit(X_train_scaled_n_scaler, y_train_balanced)
mlp_pred = mlp.predict(X_test_scaled_n_scaler)
mlp_accuracy = metrics.accuracy_score(y_test, mlp_pred)
mlp_precision = metrics.precision_score(y_test, mlp_pred)
mlp_recall = metrics.recall_score(y_test, mlp_pred)

mlp_f1_score = metrics.f1_score(y_test, mlp_pred)

mlp_cm = metrics.confusion_matrix(y_test, mlp_pred)

print(f'Accuracy: {mlp_accuracy}')
print(f'Precision: {mlp_precision}')
print(f'Recall: {mlp_recall}')
print(f'F1 Score: {mlp_f1_score}')

disp = ConfusionMatrixDisplay(confusion_matrix=mlp_cm, display_labels=np.unique(y_test))
disp.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix (MLP)')
plt.show()

RocCurveDisplay.from_estimator(mlp, X_test_scaled_n_scaler, y_test)
plt.title('ROC Curve (MLP)')
# Out:
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Accuracy: 0.9034267912772586
# Precision: 0.78125
# Recall: 0.8223684210526315
# F1 Score: 0.8012820512820513
# Text(0.5, 1.0, 'ROC Curve (MLP)')

# %%
#tune with optuna
import optuna
from sklearn.neural_network import MLPClassifier

def objective(trial):
    
        hidden_layer_sizes = trial.suggest_categorical('hidden_layer_sizes', [50, 100, 200,])
        activation = trial.suggest_categorical('activation', ['relu', 'tanh', 'logistic'])
    
        mlp = MLPClassifier(random_state=42, hidden_layer_sizes=hidden_layer_sizes, activation=activation)
        mlp.fit(X_train_scaled_n_scaler, y_train_balanced)
        mlp_pred = mlp.predict(X_test_scaled_n_scaler)
        mlp_accuracy = metrics.accuracy_score(y_test, mlp_pred)
    
        return mlp_accuracy

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2024-11-23 20:58:48,792] A new study created in memory with name: no-name-95205b47-3159-4dc2-8d21-4caf43d1f381
# [I 2024-11-23 20:58:54,006] Trial 0 finished with value: 0.867601246105919 and parameters: {'hidden_layer_sizes': 200, 'activation': 'logistic'}. Best is trial 0 with value: 0.867601246105919.
# [I 2024-11-23 20:58:58,906] Trial 1 finished with value: 0.867601246105919 and parameters: {'hidden_layer_sizes': 200, 'activation': 'logistic'}. Best is trial 0 with value: 0.867601246105919.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 20:59:01,857] Trial 2 finished with value: 0.9018691588785047 and parameters: {'hidden_layer_sizes': 50, 'activation': 'relu'}. Best is trial 2 with value: 0.9018691588785047.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 20:59:04,779] Trial 3 finished with value: 0.8894080996884736 and parameters: {'hidden_layer_sizes': 100, 'activation': 'tanh'}. Best is trial 2 with value: 0.9018691588785047.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 20:59:06,609] Trial 4 finished with value: 0.881619937694704 and parameters: {'hidden_layer_sizes': 50, 'activation': 'tanh'}. Best is trial 2 with value: 0.9018691588785047.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 20:59:10,152] Trial 5 finished with value: 0.9034267912772586 and parameters: {'hidden_layer_sizes': 200, 'activation': 'relu'}. Best is trial 5 with value: 0.9034267912772586.
# [I 2024-11-23 20:59:14,993] Trial 6 finished with value: 0.867601246105919 and parameters: {'hidden_layer_sizes': 200, 'activation': 'logistic'}. Best is trial 5 with value: 0.9034267912772586.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 20:59:19,701] Trial 7 finished with value: 0.9034267912772586 and parameters: {'hidden_layer_sizes': 200, 'activation': 'relu'}. Best is trial 5 with value: 0.9034267912772586.
# [I 2024-11-23 20:59:22,987] Trial 8 finished with value: 0.867601246105919 and parameters: {'hidden_layer_sizes': 200, 'activation': 'logistic'}. Best is trial 5 with value: 0.9034267912772586.
# [I 2024-11-23 20:59:26,069] Trial 9 finished with value: 0.867601246105919 and parameters: {'hidden_layer_sizes': 200, 'activation': 'logistic'}. Best is trial 5 with value: 0.9034267912772586.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 20:59:32,018] Trial 10 finished with value: 0.9065420560747663 and parameters: {'hidden_layer_sizes': 100, 'activation': 'relu'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 20:59:34,842] Trial 11 finished with value: 0.9065420560747663 and parameters: {'hidden_layer_sizes': 100, 'activation': 'relu'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 20:59:37,232] Trial 12 finished with value: 0.9065420560747663 and parameters: {'hidden_layer_sizes': 100, 'activation': 'relu'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 20:59:39,548] Trial 13 finished with value: 0.9065420560747663 and parameters: {'hidden_layer_sizes': 100, 'activation': 'relu'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 20:59:41,748] Trial 14 finished with value: 0.9065420560747663 and parameters: {'hidden_layer_sizes': 100, 'activation': 'relu'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 20:59:43,776] Trial 15 finished with value: 0.9065420560747663 and parameters: {'hidden_layer_sizes': 100, 'activation': 'relu'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 20:59:45,898] Trial 16 finished with value: 0.9065420560747663 and parameters: {'hidden_layer_sizes': 100, 'activation': 'relu'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 20:59:48,144] Trial 17 finished with value: 0.8894080996884736 and parameters: {'hidden_layer_sizes': 100, 'activation': 'tanh'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 20:59:50,312] Trial 18 finished with value: 0.9065420560747663 and parameters: {'hidden_layer_sizes': 100, 'activation': 'relu'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 20:59:52,100] Trial 19 finished with value: 0.9018691588785047 and parameters: {'hidden_layer_sizes': 50, 'activation': 'relu'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 20:59:54,697] Trial 20 finished with value: 0.8894080996884736 and parameters: {'hidden_layer_sizes': 100, 'activation': 'tanh'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 20:59:56,872] Trial 21 finished with value: 0.9065420560747663 and parameters: {'hidden_layer_sizes': 100, 'activation': 'relu'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 20:59:59,230] Trial 22 finished with value: 0.9065420560747663 and parameters: {'hidden_layer_sizes': 100, 'activation': 'relu'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 21:00:01,469] Trial 23 finished with value: 0.9065420560747663 and parameters: {'hidden_layer_sizes': 100, 'activation': 'relu'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 21:00:03,775] Trial 24 finished with value: 0.9065420560747663 and parameters: {'hidden_layer_sizes': 100, 'activation': 'relu'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 21:00:06,033] Trial 25 finished with value: 0.9065420560747663 and parameters: {'hidden_layer_sizes': 100, 'activation': 'relu'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 21:00:07,856] Trial 26 finished with value: 0.9018691588785047 and parameters: {'hidden_layer_sizes': 50, 'activation': 'relu'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 21:00:10,028] Trial 27 finished with value: 0.9065420560747663 and parameters: {'hidden_layer_sizes': 100, 'activation': 'relu'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 21:00:12,739] Trial 28 finished with value: 0.8894080996884736 and parameters: {'hidden_layer_sizes': 100, 'activation': 'tanh'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 21:00:15,532] Trial 29 finished with value: 0.9065420560747663 and parameters: {'hidden_layer_sizes': 100, 'activation': 'relu'}. Best is trial 10 with value: 0.9065420560747663.
# c:\Users\bwelo\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-11-23 21:00